# %% [markdown]
# <a href="https://colab.research.google.com/github/poojappt/Hotel-Booking-EDA/blob/main/Poojappt_Hotel_Booking_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ## <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ## <b> Explore and analyze the data to discover important factors that govern the bookings. </b>

# %% [markdown]
# Exploratory data anyalysis (EDA) is nothing but a data exploration technique to understanda the various aspects of data. While exploring the data few things we need to keep in mind like we have to make sure that we have indentified the important data in dataset,data is clean & does not have any redundancies on missing values or even the null values in the data sets. And we must understand the relationship between the variables through EDA. And last but not the least we must be able to derive the conclusions on gather insights about the data or conclusive interpretation in order to move on to more complex processes in the data processing life cycles.
#
#
# So the main objective of EDA is to filter the data & helps us to understand the relationship between th variables which gives us wider prospective on the data.
#
# **STEPS INVOLVED IN EDA**:-
#
# 1.Understand the Data ---> You have to be pretty sure that what kind of data you are working at i.e. what are the variables(number of columns & rows, missing values, important variables)
#
# 2.To clean the data ---> It involves the removal of redundancies, outliers.
# Redundancies are irregularities in the data, it can be some columns or data that are not necessary for making our conclusions.
#  It can be outliers that can cause noise in the data(byoverfiting or underfiting).
#
#  3.Analyse the relationship between variables and present visually

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Understanding the data**

# %%
#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

# %%
# mounting the drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# uploading the dataset
df = pd.read_csv('/content/drive/MyDrive/Dataset/ Hotel Bookings.csv')

# %%
#Data exploration
df.head(15)
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          7               2015
# 3   Resort Hotel            0         13               2015
# 4   Resort Hotel            0         14               2015
# 5   Resort Hotel            0         14               2015
# 6   Resort Hotel            0          0               2015
# 7   Resort Hotel            0          9               2015
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
#
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
#Finding null values
df.isnull().sum().sort_values(ascending = False)
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %%
df['children'].unique()
# Out:
# array([ 0.,  1.,  2., 10.,  3., nan])

# %%
df['agent'].unique()
# Out:
# array([ nan, 304., 240., 303.,  15., 241.,   8., 250., 115.,   5., 175.,
#        134., 156., 243., 242.,   3., 105.,  40., 147., 306., 184.,  96.,
#          2., 127.,  95., 146.,   9., 177.,   6., 143., 244., 149., 167.,
#        300., 171., 305.,  67., 196., 152., 142., 261., 104.,  36.,  26.,
#         29., 258., 110.,  71., 181.,  88., 251., 275.,  69., 248., 208.,
#        256., 314., 126., 281., 273., 253., 185., 330., 334., 328., 326.,
#        321., 324., 313.,  38., 155.,  68., 335., 308., 332.,  94., 348.,
#        310., 339., 375.,  66., 327., 387., 298.,  91., 245., 385., 257.,
#        393., 168., 405., 249., 315.,  75., 128., 307.,  11., 436.,   1.,
#        201., 183., 223., 368., 336., 291., 464., 411., 481.,  10., 154.,
#        468., 410., 390., 440., 495., 492., 493., 434.,  57., 531., 420.,
#        483., 526., 472., 429.,  16., 446.,  34.,  78., 139., 252., 270.,
#         47., 114., 301., 193., 182., 135., 350., 195., 352., 355., 159.,
# ...

# %%
df['company'].unique()
# Out:
# array([ nan, 110., 113., 270., 178., 240., 154., 144., 307., 268.,  59.,
#        204., 312., 318.,  94., 174., 274., 195., 223., 317., 281., 118.,
#         53., 286.,  12.,  47., 324., 342., 373., 371., 383.,  86.,  82.,
#        218.,  88.,  31., 397., 392., 405., 331., 367.,  20.,  83., 416.,
#         51., 395., 102.,  34.,  84., 360., 394., 457., 382., 461., 478.,
#        386., 112., 486., 421.,   9., 308., 135., 224., 504., 269., 356.,
#        498., 390., 513., 203., 263., 477., 521., 169., 515., 445., 337.,
#        251., 428., 292., 388., 130., 250., 355., 254., 543., 531., 528.,
#         62., 120.,  42.,  81., 116., 530., 103.,  39.,  16.,  92.,  61.,
#        501., 165., 291., 290.,  43., 325., 192., 108., 200., 465., 287.,
#        297., 490., 482., 207., 282., 437., 225., 329., 272.,  28.,  77.,
#        338.,  72., 246., 319., 146., 159., 380., 323., 511., 407., 278.,
#         80., 403., 399.,  14., 137., 343., 346., 347., 349., 289., 351.,
# ...

# %%
df['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %% [markdown]
# We have 4 columns with missing values. There are various ways of treating missing values in data sets, which technique to use when is dependent upon the type of data we are dealing with.
# For numerical column, we can replace the missing values with mean values or median values. Before replacing with mean it is advicable to check that variable shouldn't have extreme values because mean is influenced by outliers, in these type of cases we can use median which is not affected by outliers.
# For categorical data we can replace the missing values with mode values.
#
# In our data set 3 columns(company,agent & children) are of numerical data type and country column is categorical data type. By looking at the unique values of these columns we can say that these are free from outliers, so we'll use mean to replace the numerical data.

# %%
# Handling the missing values in numerical columns
children_mean= df['children'].mean()
agent_mean = df['agent'].mean()
company_mean = df['company'].mean()

# Replacing the null values with mean
df['children'].replace(np.nan,children_mean,inplace = True)
df['agent'].replace(np.nan,agent_mean,inplace = True)
df['company'].replace(np.nan,company_mean,inplace = True)

# %%
# Handling the missing values in categorical columns
country_mode = df['country'].mode().values[0] # if we don't use values[0] country_mode will give a series and 
#we can't replace a null value in a series.

# Replacing the null values with mode
df['country'] = df['country'].replace(np.nan,country_mode)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
# Handling the duplicate record 
duplicate = df.duplicated()
print(duplicate.sum())
df[duplicate]
# Out:
# 32013
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 5       Resort Hotel            0         14               2015
# 22      Resort Hotel            0         72               2015
# 43      Resort Hotel            0         70               2015
# 138     Resort Hotel            1          5               2015
# 200     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119349    City Hotel            0        186               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 5                    July                        27
# 22                   July                        27
# ...

# %% [markdown]
# since we have 32013 dupliate records in the data, we will remove this from the data set so that we get only distinct records.

# %%
# Drop the duplicates
df.drop_duplicates(inplace = True)

#verification
df.duplicated().sum()
# Out:
# 0

# %%
# Handling the outliers
df.boxplot(column=['company'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
df.boxplot(column=['agent'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#Corrrelation of dataset
correlated_data = df[['lead_time','previous_cancellations','is_canceled','stays_in_weekend_nights','stays_in_week_nights','is_repeated_guest',\
                      'booking_changes','babies','adults','is_repeated_guest']]
corr_df = correlated_data.corr()
corr_df
# Out:
#                          lead_time  previous_cancellations  is_canceled  \
# lead_time                 1.000000                0.005361     0.184723
# previous_cancellations    0.005361                1.000000     0.051462
# is_canceled               0.184723                0.051462     1.000000
# stays_in_weekend_nights   0.235062               -0.020647     0.060098
# stays_in_week_nights      0.310061               -0.018793     0.082858
# is_repeated_guest        -0.147048                0.206372    -0.089670
# booking_changes           0.076979               -0.010274    -0.093681
# babies                   -0.003630               -0.005397    -0.020554
# adults                    0.140370               -0.042118     0.081718
# is_repeated_guest        -0.147048                0.206372    -0.089670
#
#                          stays_in_weekend_nights  stays_in_week_nights  \
# lead_time                               0.235062              0.310061
# ...

# %%
#representing correlation using heatmap
plt.figure(figsize=(10,6))
sns.heatmap(corr_df,annot = True)

# %% [markdown]
# # **Question 1) In which month of the year pre-booking is highest ? what is the trend of advance booking over the years?**

# %%
new_df1 = df.groupby(['arrival_date_year','arrival_date_month'],as_index = False)['previous_bookings_not_canceled'].count()
new_df1
# Out:
#     arrival_date_year arrival_date_month  previous_bookings_not_canceled
# 0                2015             August                            2453
# 1                2015           December                            1982
# 2                2015               July                            1674
# 3                2015           November                            1665
# 4                2015            October                            2699
# 5                2015          September                            2839
# 6                2016              April                            3769
# 7                2016             August                            4423
# 8                2016           December                            3147
# 9                2016           February                            2801
# 10               2016            January                            1849
# 11               2016               July                            3850
# ...

# %%
month = new_df1['arrival_date_month']
previous_booking = new_df1['previous_bookings_not_canceled']

plt.rcParams['figure.figsize'] = (15,5)

plt.bar(month,previous_booking,color = 'maroon',width = 0.5)

plt.xlabel('month')
plt.ylabel('previous_booking')
plt.title('month wise booking')
# Out:
# Text(0.5, 1.0, 'month wise booking')

# %% [markdown]
# ### We can see that in May month previous booking is highest and in December month it is lowest.

# %%
year= new_df1['arrival_date_year']
previous_booking = new_df1['previous_bookings_not_canceled']

plt.rcParams['figure.figsize'] = (5,5)

plt.bar(year,previous_booking,color = 'maroon',width = 0.3)

plt.xlabel('year')
plt.ylabel('previous_booking')
plt.title('year wise booking')
# Out:
# Text(0.5, 1.0, 'year wise booking')

# %% [markdown]
# ### We can conclude that previous booking has increased over the years.

# %% [markdown]
# ## **Question 2) A hotel booking׳s likelihood to be canceled ?**

# %%
df.head(2)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
#
#        agent     company days_in_waiting_list customer_type  adr  \
# 0  86.693382  189.266735                    0     Transient  0.0
# 1  86.693382  189.266735                    0     Transient  0.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# ...

# %%
booking_data = df['is_canceled'].value_counts()

# %%
status = ['Not canceled','canceled']
plt.pie(booking_data,labels = status,autopct = '%2.1f%%')
plt.show()

# %% [markdown]
# ### From Above plot we can see that 37% bookings were canceled

# %% [markdown]
# # **Question 3) What is the Percentage of each market segment ? & overview of distribution channel.**

# %% [markdown]
# Market segmentation involves analyzing the target markets for the hotel industry and segmenting them based on the pricing sensitivity and booking behaviors. Market segmentation in the hotel industry helps identify the reason for a drop in the bookings.
#
# Transient – These are the guests who are not linked to any group or company. They are the ones that make individual bookings at your Best Available Rate (BAR) or publically available dynamic charges.
#
# Corporate – These are the guests that stay at the hotel at discounted company rates. The discounted rates are available on a contract basis to corporate clients who bring in frequent business.
#
# Group –This segment of the guests stays at your hotel under contracted rates for a large group or for an event. The rates are flexible depending on the requirements.
#
# Wholesale –Rooms under this segment are available at discounted rates to tour operators or booking agents on buying bulk tickets.
#
# Direct –This segment consists of direct bookings with the hotel done over phone calls or emails.
#
# Website –Under this segment, secure reservations are made through a hotel reservation system on the hotel’s website.
#
# OTAs – OTAs(Online Travel Agency) are online third-party travel agencies that allow people to make reservations for various hotels through their platform. For example, Trivago, TripAdvisor, etc.
#
# GDS – GDS or global distribution system is a large network that acts as a conduit between hotels and travel sites.

# %%
df['market_segment'].unique()
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO',
#        'Complementary', 'Groups', 'Undefined', 'Aviation'], dtype=object)

# %%
segmentation = df['market_segment']
segmentation.value_counts(normalize = True)
# Out:
# Online TA        0.590728
# Offline TA/TO    0.158921
# Direct           0.135024
# Groups           0.056537
# Corporate        0.048136
# Complementary    0.008034
# Aviation         0.002598
# Undefined        0.000023
# Name: market_segment, dtype: float64

# %%
sns.countplot(data = df, x = 'market_segment',palette ='dark')
sns.set(rc = {'figure.figsize':(15,5)})
plt.show()

# %% [markdown]
# Booking through online travel agencies are highest as compared to other.

# %%
df['distribution_channel'].unique()
# Out:
# array(['Direct', 'Corporate', 'TA/TO', 'Undefined', 'GDS'], dtype=object)

# %%
channel = df['distribution_channel']
channel.value_counts(normalize = True)
# Out:
# TA/TO        0.791238
# Direct       0.148552
# Corporate    0.058082
# GDS          0.002071
# Undefined    0.000057
# Name: distribution_channel, dtype: float64

# %%
sns.countplot(data = df, x = 'distribution_channel',palette = 'dark').set_title('types of distribution channel',fontsize = 10)
sns.set(rc = {'figure.figsize':(10,5)})
plt.show()

# %% [markdown]
# ### As majority of the target market is covered by OTA.

# %% [markdown]
# # **Question 4) Show the proportion of reservation between hotel types.**

# %%
sns.countplot(data= df,x ='hotel', palette='dark')
plt.title("hotel")
plt.show()

# %% [markdown]
# The length of these bar represents that the percent of city hotel is more as compare to resort hotel.

# %% [markdown]
# # **Question 5) What is the most reserved room type ?**

# %%
df.reserved_room_type.value_counts(normalize = True)
# Out:
# A    0.647035
# D    0.199103
# E    0.069217
# F    0.032297
# G    0.023484
# B    0.011433
# C    0.010472
# H    0.006821
# L    0.000069
# P    0.000069
# Name: reserved_room_type, dtype: float64

# %%
room_types = df.reserved_room_type.value_counts(normalize = True)
sns.countplot(data = df, x = 'reserved_room_type',palette = 'dark')
sns.set(rc = {'figure.figsize':(10,5)})
plt.show()

# %% [markdown]
# It can be concluded tha room type A is most reserved room type.

# %%
avg_rate_df = df.groupby(['arrival_date_year'])['adr'].mean()
avg_rate_df
# Out:
# arrival_date_year
# 2015     92.164670
# 2016    101.542981
# 2017    118.725867
# Name: adr, dtype: float64

# %%
avg_rate_df = df.groupby(['arrival_date_year'])['adr'].median()
avg_rate_df
# Out:
# arrival_date_year
# 2015     85.5
# 2016     94.5
# 2017    110.0
# Name: adr, dtype: float64

# %% [markdown]
# # **Question 6) What is the proportion of high number of special requests in city hotel and resort hotel respectivly ?**

# %%
sns.countplot(data = df, x = 'total_of_special_requests', hue = 'hotel',palette = 'dark')
plt.show()

# %% [markdown]
# Total of special requests are more in city hotels as comapre to Resort hotel.

# %% [markdown]
# # **Question 7) Overview of customer type**

# %%
sns.countplot(data = df, x = 'customer_type',palette = 'dark')
sns.set(rc = {'figure.figsize':(5,5)})
plt.title('type_of_customer')
plt.show()

# %% [markdown]
# Majority of the booking are transient.

# %% [markdown]
# # **Question 8) Relationship between cancellation and market segment ?**

# %%
sns.countplot(data = df, x = 'market_segment', hue = 'is_canceled',palette = 'dark')
plt.show()

# %% [markdown]
# It is easily interpretable that Online TA segment has more cancellation as compared to offline TA.
